# %% [markdown]
# # 03 - CNN Baseline
#
# Goal: establish a cheap spatial baseline before using transformer attention.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import torch
from dfm.models.cnn_baseline import CNNBaseline

# %%
batch_size = 8
channels = 12
patch_size = 32
num_classes = 5

x = torch.randn(batch_size, channels, patch_size, patch_size)
model = CNNBaseline(in_channels=channels, num_classes=num_classes)
logits = model(x)

print("Input:", x.shape)
print("Logits:", logits.shape)
# Out:
# Input: torch.Size([8, 12, 32, 32])
# Logits: torch.Size([8, 5])
